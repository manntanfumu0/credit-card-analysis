# %%
import pandas as pd

df = pd.read_csv("../data/processed/dados_limpos.csv")

print("Dados carregados com sucesso")
# Out:
# Dados carregados com sucesso

# %%
df["aprovado"].value_counts(normalize=True) * 100
# Out:
# Series([], Name: proportion, dtype: float64)

# %%
print(df.columns)
# Out:
# Index(['genero', 'idade', 'divida', 'casadoa', 'cliente_do_banco',
#        'setor_da_industria', 'etnia', 'anos_empregado',
#        'inadimplencia_anterior', 'empregadoa', 'pontuacao_de_credito',
#        'carteira_de_motorista', 'cidadania', 'codigo_postal', 'renda',
#        'aprovado'],
#       dtype='object')

# %%
print(df.shape)
df.head()
# Out:
# (672, 16)
#    genero  idade  divida  casadoa  cliente_do_banco  setor_da_industria  \
# 0       1  30.83   0.000        1               NaN                   7
# 1       0  58.67   4.460        1               NaN                   9
# 2       0  24.50   0.500        1               NaN                   9
# 3       1  27.83   1.540        1               NaN                   7
# 4       1  20.17   5.625        1               NaN                   7
#
#    etnia  anos_empregado  inadimplencia_anterior  empregadoa  \
# 0      4            1.25                       1         NaN
# 1      1            3.04                       1         NaN
# 2      1            1.50                       1         NaN
# 3      4            3.75                       1         NaN
# 4      4            1.71                       1         NaN
#
#    pontuacao_de_credito  carteira_de_motorista  cidadania  codigo_postal  \
# 0                     1                      0          0            202
# ...

# %%
df["aprovado"].value_counts(normalize=True) * 100
# Out:
# Series([], Name: proportion, dtype: float64)

# %%
df = pd.read_csv("../data/processed/dados_limpos.csv")

# %%
df["aprovado"].value_counts(normalize=True) * 100
# Out:
# aprovado
# 0    55.952381
# 1    44.047619
# Name: proportion, dtype: float64

# %%
df.groupby("aprovado")["renda"].mean()
# Out:
# aprovado
# 0     200.417553
# 1    2058.395270
# Name: renda, dtype: float64

# %%
df.groupby("aprovado")["divida"].mean()
# Out:
# aprovado
# 0    3.752420
# 1    5.694645
# Name: divida, dtype: float64

# %%
df.groupby("inadimplencia_anterior")["aprovado"].mean()
# Out:
# inadimplencia_anterior
# 0    0.067901
# 1    0.787356
# Name: aprovado, dtype: float64

# %%
df.groupby("aprovado")["pontuacao_de_credito"].mean()
# Out:
# aprovado
# 0    0.627660
# 1    4.614865
# Name: pontuacao_de_credito, dtype: float64
